# %% [markdown]
# <a href="https://colab.research.google.com/github/giangnt071098/DL_Tutorial/blob/master/semanticroad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install Pillow
# !pip install scipy==1.1.0
# !python3 '/content/drive/My Drive/sematic_road/main (1).py'
# Out:
# ...
#      |████████████████████████████████| 31.2MB 1.7MB/s
# ...
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.3.0
#     Uninstalling scipy-1.3.0:
#       Successfully uninstalled scipy-1.3.0
# ...
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0719 09:12:19.205480 139950463575936 deprecation_wrapper.py:119] From /content/drive/My Drive/sematic_road/main (1).py:23: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# TensorFlow Version: 1.14.0
# 2019-07-19 09:12:19.221720: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-07-19 09:12:19.221921: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x22ed480 executing computations on platform Host. Devices:
# ...
